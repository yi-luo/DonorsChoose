# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
ls
# Out:
# Projects.csv*              resources.csv
# data_analysis.ipynb        result.csv
# logistic_regression.ipynb  test.csv
# projects2.csv              train.csv

# %%
projects_df = pd.read_csv("result.csv")
resources_df=pd.read_csv("resources.csv")
projects_df2 = pd.read_csv("Projects.csv")

# %%
resources_df.head(20)
# Out:
#          id                                        description  quantity  \
# 0   p233245  LC652 - Lakeshore Double-Space Mobile Drying Rack         1
# 1   p069063        Bouncy Bands for Desks (Blue support pipes)         3
# 2   p069063  Cory Stories: A Kid's Book About Living With Adhd         1
# 3   p069063  Dixon Ticonderoga Wood-Cased #2 HB Pencils, Bo...         2
# 4   p069063  EDUCATIONAL INSIGHTS FLUORESCENT LIGHT FILTERS...         3
# 5   p069063  Last to Finish: A Story About the Smartest Boy...         1
# 6   p069063  Mrs. Gorski, I Think I Have the Wiggle Fidgets...         1
# 7   p069063  See-N-Read 1503905CQ Reading Tool - Book Size,...         2
# 8   p096795  Brewster WPD90218 Wall Pops Flirt Dot, Set of ...         2
# 9   p096795  Brewster Wall Pops WPE99065 Peel & Stick Calyp...         2
# 10  p096795  TIME For Kids - 3-4 PRINT Bundle - 24 issues /...        40
# 11  p149007  Ahora, Spanish, Grades 6 - 12, Level 2 (min. 1...        60
# ...

# %%
projects_df2.head(3)
# Out:
#                          Project ID                         School ID  \
# 0  7685f0265a19d7b52a470ee4bac883ba  e180c7424cb9c68cb49f141b092a988f
# 1  f9f4af7099061fb4bf44642a03e5c331  08b20f1e2125103ed7aa17e8d76c71d4
# 2  afd99a01739ad5557b51b1ba0174e832  1287f5128b1f36bf8434e5705a7cc04d
#
#                          Teacher ID  Teacher Project Posted Sequence  \
# 0  4ee5200e89d9e2998ec8baad8a3c5968                               25
# 1  cca2d1d277fb4adb50147b49cdc3b156                                3
# 2  6c5bd0d4f20547a001628aefd71de89e                                1
#
#   Project Type                                      Project Title  \
# 0  Teacher-Led             Stand Up to Bullying: Together We Can!
# 1  Teacher-Led                                 Learning in Color!
# 2  Teacher-Led  Help Second Grade ESL Students Develop Languag...
#
#                                        Project Essay  \
# 0  Did you know that 1-7 students in grades K-12 ...
# ...

# %%
projects_df2[projects_df2['Teacher ID']=='484aaf11257089a66cfedc9461c6bd0a']
# Out:
#                                Project ID                         School ID  \
# 436389   becfcf432dd8231279e4884b9fd6f662  2f2ddae03ade57cae0417d32c99c4e6f
# 439772   8ee9c8188557376256cb69022050565a  2f2ddae03ade57cae0417d32c99c4e6f
# 446945   4071470a117cccc49521b126a0d8ce20  2f2ddae03ade57cae0417d32c99c4e6f
# 458108   47a4976672db34aef6c314b262fe4cc0  2f2ddae03ade57cae0417d32c99c4e6f
# 469521   1e7661b30cfb5ba242f8ab61b4bc7a96  2f2ddae03ade57cae0417d32c99c4e6f
# 477963   5bad1d9a88f835db5210afd9e23ba49e  2f2ddae03ade57cae0417d32c99c4e6f
# 479928   8f35a0926ac38b70d01d967247dfa5f3  2f2ddae03ade57cae0417d32c99c4e6f
# 485471   72f96ce62445c8a429551c268c238eae  2f2ddae03ade57cae0417d32c99c4e6f
# 500700   0294ba6622723929dc7bc07c9b0d5699  2f2ddae03ade57cae0417d32c99c4e6f
# 501110   0df0ed789993e653c6ced5e9c723bc67  2f2ddae03ade57cae0417d32c99c4e6f
# 501154   f18f639af398c718f90d7c75fa195636  2f2ddae03ade57cae0417d32c99c4e6f
# ...

# %%
projects_df.head(3)
# Out:
#    Unnamed: 0  Unnamed: 0.1       id                        teacher_id  \
# 0           0             1  p039565  df72a3ba8089423fa8a94be88060f6ed
# 1           1             5  p063374  403c6783e9286e51ab318fba40f8d729
# 2           2             8  p114989  b580c11b1497a0a67317763b7f03eb27
#
#   teacher_prefix school_state project_submitted_datetime  \
# 0           Mrs.           GA        2017-04-26 15:57:28
# 1           Mrs.           DE        2016-11-05 10:01:51
# 2            Ms.           IN        2016-09-13 22:35:57
#
#   project_grade_category             project_subject_categories  \
# 0             Grades 3-5      Music & The Arts, Health & Sports
# 1          Grades PreK-2  Applied Learning, Literacy & Language
# 2             Grades 6-8                         Math & Science
#
#                project_subject_subcategories  \
# 0               Performing Arts, Team Sports
# 1  Character Education, Literature & Writing
# 2                                Mathematics
#
# ...

# %%
projects_df['total_cost'].plot(kind='hist',)

# %%
projects_df['project_is_approved'].value_counts()
# Out:
# 1    154346
# 0     27734
# Name: project_is_approved, dtype: int64

# %%
projects_df['project_is_approved'].value_counts().plot.pie()

# %%
projects_df['school_state'].value_counts().head(10).plot(kind='bar',figsize=(15,3))

# %%
projects_df['project_subject_categories'].value_counts().head(10).plot(kind='bar',figsize=(15,3),main=)

# %%
projects_df['project_submitted_datetime'] = pd.to_datetime(projects_df['project_submitted_datetime'])
projects_df['project_submitted_datetime'].describe()
# Out:
# count                  182080
# unique                 180439
# top       2016-09-01 00:00:03
# freq                       30
# first     2016-04-27 00:03:38
# last      2017-04-30 23:50:43
# Name: project_submitted_datetime, dtype: object

# %%
projects_df['project_essay_1'].head(2).values
# Out:
# array(['Most of my kindergarten students come from low-income households and are considered \\"at-risk\\". These kids walk to school alongside their parents and most have never been further than walking distance from their house. For 80% of my students, English is not their first language or the language spoken at home. \\r\\n\\r\\nWhile my kindergarten kids have many obstacles in front of them, they come to school each day excited and ready to learn. Most students started the year out never being in a school setting. At the start of the year many had never been exposed to letters. Each day they soak up more knowledge and try their hardest to succeed. They are highly motivated to learn new things every day. We are halfway through the year and they are starting to take off. They know know all letters, some sight words, numbers to 20, and a majority of their letter sounds because of their hard work and determination. I am excited to see the places we will go from here!',
# ...

# %%
students_df = pd.read_csv("data.csv")

## Example 1: Filter for female students only
students_df[students_df['GENDER']=='F']

## Example 2: Filter for Engineering students only
students_df[students_df['MAJOR']=='Engineering']

# %%
## Enter code below

students_df[students_df['PYTHON EXPERIENCE?']=='YES']
